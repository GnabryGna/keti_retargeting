# %%
import pickle

path = "datasets/datasets_0.pkl"
with open(f"{path}", "rb") as f:
    data = pickle.load(f)

print(data.keys())
# print(data["observations"])
print(data["actions"])
print(data["reward"])
print(len(data["reward"]))
# Out:
# dict_keys(['observations', 'actions', 'reward'])
# ...
